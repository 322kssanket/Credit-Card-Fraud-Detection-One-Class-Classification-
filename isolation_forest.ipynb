# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
df['Amount'] = StandardScaler().fit_transform(df['Amount'].values.reshape(-1, 1))
df['Amount']
# Out:
# 0         0.244964
# 1        -0.342475
# 2         1.160686
# 3         0.140534
# 4        -0.073403
#             ...
# 284802   -0.350151
# 284803   -0.254117
# 284804   -0.081839
# 284805   -0.313249
# 284806    0.514355
# Name: Amount, Length: 284807, dtype: float64

# %%
df['Time'] = StandardScaler().fit_transform(df['Time'].values.reshape(-1, 1))
df['Time']
# Out:
# 0        -1.996583
# 1        -1.996583
# 2        -1.996562
# 3        -1.996562
# 4        -1.996541
#             ...
# 284802    1.641931
# 284803    1.641952
# 284804    1.641974
# 284805    1.641974
# 284806    1.642058
# Name: Time, Length: 284807, dtype: float64

# %%
df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
# Histograms
df['Amount'].plot(kind='hist', bins=10)
plt.title('Transaction Amount Distribution')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplots
df.boxplot(column='Amount', by='Class')
plt.title('Transaction Amount Distribution by Fraudulent Status')
plt.xlabel('Fraudulent Status')
plt.ylabel('Transaction Amount')
plt.show()

# %%
# Boxplots
df.boxplot(column='Time', by='Class')
plt.title('Transaction Time Distribution by Fraudulent Status')
plt.xlabel('Fraudulent Status')
plt.ylabel('Transaction Time')
plt.show()

# %%
(df['Class'] == 1).sum()
# Out:
# 492

# %%
df['Class'].describe()
# Out:
# count    284807.000000
# mean          0.001727
# std           0.041527
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: Class, dtype: float64

# %%
df['Time'].describe()
# Out:
# count    2.848070e+05
# mean    -3.065637e-16
# std      1.000002e+00
# min     -1.996583e+00
# 25%     -8.552120e-01
# 50%     -2.131453e-01
# 75%      9.372174e-01
# max      1.642058e+00
# Name: Time, dtype: float64

# %%
df['Amount'].describe()
# Out:
# count    2.848070e+05
# mean     2.913952e-17
# std      1.000002e+00
# min     -3.532294e-01
# 25%     -3.308401e-01
# 50%     -2.652715e-01
# 75%     -4.471707e-02
# max      1.023622e+02
# Name: Amount, dtype: float64

# %%
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# seperate data into training and test set
X = df.iloc[:,:-1]
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# this function creates and returns a model for isolation forest for a given conatmination value
def iso_forest(X_train, cont):
    model = IsolationForest(contamination=cont)
    model.fit(X_train)
    return model

# %%
# create models with different contamination values
cont_values = [0.001, 0.01, 0.1]
models = [iso_forest(X_train, c) for c in cont_values]

# Make predictions on the test set
y_pred_test = [model.predict(X_test) for model in models]

# %%
y_pred_test
# Out:
# [array([1, 1, 1, ..., 1, 1, 1]),
#  array([1, 1, 1, ..., 1, 1, 1]),
#  array([1, 1, 1, ..., 1, 1, 1])]

# %%
# print number of anomalies predicted for each contamination value
for i in range(3):
    print(f'Number of anomalies for contamination value {cont_values[i]}: {(y_pred_test[i] == -1).sum()}')
# Out:
# Number of anomalies for contamination value 0.001: 44
# Number of anomalies for contamination value 0.01: 540
# Number of anomalies for contamination value 0.1: 5718

# %%
# modify predicted values to have same class values as original data
modified_pred = [pd.Series(pred).replace({-1: 1, 1: 0}) for pred in y_pred_test]
df_combined = pd.concat(modified_pred, axis=1)
df_combined
# Out:
#        0  1  2
# 0      0  0  0
# 1      0  0  0
# 2      0  0  0
# 3      0  0  0
# 4      0  0  0
# ...   .. .. ..
# 56957  0  0  0
# 56958  0  0  0
# 56959  0  0  0
# 56960  0  0  0
# 56961  0  0  0
#
# [56962 rows x 3 columns]

# %%
def plot_figures(index):
    fig, (ax0, ax1) = plt.subplots(1, 2, sharey=True, figsize=(20, 8))

    #original
    ax0.set_title(f'Original (Contamination : {cont_values[index]})')
    ax0.scatter(X_test['V1'], X_test['V2'],c=y_test,cmap='rainbow', s=50)

    # predicted
    ax1.set_title(f'Predicted (Contamination : {cont_values[index]})')
    ax1.scatter(X_test['V1'], X_test['V2'],c=df_combined[index],cmap='rainbow', s=50)

# %%
# plot graph for attributes V2 and V3 for original and predicted values with contamination value = 0.001
plot_figures(0)

# %%
# plot graph for attributes V2 and V3 for original and predicted values with contamination value = 0.01
plot_figures(1)

# %%
# plot graph for attributes V2 and V3 for original and predicted values with contamination value = 0.1
plot_figures(2)

# %%
# print performance for different hyper-paramaters
def print_performance():
    for i in range(3):
        precision = precision_score(y_test, modified_pred[i])
        recall = recall_score(y_test, modified_pred[i])
        f1 = f1_score(y_test, modified_pred[i])

        print(f"Precision (Contamination : {cont_values[i]}) : {precision:.2f}")
        print(f"Recall    (Contamination : {cont_values[i]}) : {recall:.2f}")
        print(f"F1-score  (Contamination : {cont_values[i]}) : {f1:.2f}")
        print()

# %%
print_performance()
# Out:
# Precision (Contamination : 0.001) : 0.23
# Recall    (Contamination : 0.001) : 0.11
# F1-score  (Contamination : 0.001) : 0.14
#
# Precision (Contamination : 0.01) : 0.11
# Recall    (Contamination : 0.01) : 0.63
# F1-score  (Contamination : 0.01) : 0.19
#
# Precision (Contamination : 0.1) : 0.01
# Recall    (Contamination : 0.1) : 0.89
# F1-score  (Contamination : 0.1) : 0.03
